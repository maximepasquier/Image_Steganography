# %%
import numpy as np
import skimage
import os
import cv2
import scipy.signal
import random
import math
import matplotlib.pyplot as plt

# %%
img = cv2.imread(os.path.abspath("../Images/img.png"),1)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img_rgb)
plt.show()

# %%
img_e_LSB = cv2.imread(os.path.abspath("../Images/img_e_LSB.png"),1)
img_e_LSB_rgb = cv2.cvtColor(img_e_LSB, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img_e_LSB_rgb)
plt.show()
