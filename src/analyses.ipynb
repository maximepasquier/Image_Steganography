# %%
import numpy as np
import skimage
import os
import cv2
import scipy.signal
import random
import math
import matplotlib.pyplot as plt

# %%
def Mean_Square_Error(X,Y):
    return (np.square(X - Y)).mean()

# %%
def Peak_Signal_to_Noise_Ratio(X,Y):
    mse = Mean_Square_Error(X,Y)
    if(mse == 0):
        return 100
    max_pixel = 256
    psnr = 20 * math.log10(max_pixel / math.sqrt(mse))
    return psnr

# %% [markdown]
# ## LSB

# %%
cover = cv2.imread(os.path.abspath("../Images/cover.png"),1)
cover = cv2.cvtColor(cover, cv2.COLOR_BGR2RGB)

secret = cv2.imread(os.path.abspath("../Images/secret.png"),1)
secret = cv2.cvtColor(secret, cv2.COLOR_BGR2RGB)

stego_LSB_2 = cv2.imread(os.path.abspath("../Images/stego_LSB_2.png"),1)
stego_LSB_2 = cv2.cvtColor(stego_LSB_2, cv2.COLOR_BGR2RGB)

stego_LSB_4 = cv2.imread(os.path.abspath("../Images/stego_LSB_4.png"),1)
stego_LSB_4 = cv2.cvtColor(stego_LSB_4, cv2.COLOR_BGR2RGB)

stego_LSB_6 = cv2.imread(os.path.abspath("../Images/stego_LSB_6.png"),1)
stego_LSB_6 = cv2.cvtColor(stego_LSB_6, cv2.COLOR_BGR2RGB)

reconstructed_LSB_2 = cv2.imread(os.path.abspath("../Images/reconstructed_LSB_2.png"),1)
reconstructed_LSB_2 = cv2.cvtColor(reconstructed_LSB_2, cv2.COLOR_BGR2RGB)

reconstructed_LSB_4 = cv2.imread(os.path.abspath("../Images/reconstructed_LSB_4.png"),1)
reconstructed_LSB_4 = cv2.cvtColor(reconstructed_LSB_4, cv2.COLOR_BGR2RGB)

reconstructed_LSB_6 = cv2.imread(os.path.abspath("../Images/reconstructed_LSB_6.png"),1)
reconstructed_LSB_6 = cv2.cvtColor(reconstructed_LSB_6, cv2.COLOR_BGR2RGB)

# %%
print("LBS_2")
print("Cover-Stego")
print("MSE =",Mean_Square_Error(cover,stego_LSB_2))
print("PSNR =",Peak_Signal_to_Noise_Ratio(cover,stego_LSB_2))
print("Secret-Reconstruction")
print("MSE =",Mean_Square_Error(secret,reconstructed_LSB_2))
print("PSNR =",Peak_Signal_to_Noise_Ratio(secret,reconstructed_LSB_2))
# Out:
# LBS_2
# Cover-Stego
# MSE = 2.382866294992175
# PSNR = 44.39380256290747
# Secret-Reconstruction
# MSE = 106.46137641823161
# PSNR = 27.892878538425844

# %%
print("LBS_4")
print("Cover-Stego")
print("MSE =",Mean_Square_Error(cover,stego_LSB_4))
print("PSNR =",Peak_Signal_to_Noise_Ratio(cover,stego_LSB_4))
print("Secret-Reconstruction")
print("MSE =",Mean_Square_Error(secret,reconstructed_LSB_4))
print("PSNR =",Peak_Signal_to_Noise_Ratio(secret,reconstructed_LSB_4))
# Out:
# LBS_4
# Cover-Stego
# MSE = 39.26559198943662
# PSNR = 32.22467781126009
# Secret-Reconstruction
# MSE = 77.56669723200314
# PSNR = 29.268046309218526

# %%
print("LBS_6")
print("Cover-Stego")
print("MSE =",Mean_Square_Error(cover,stego_LSB_6))
print("PSNR =",Peak_Signal_to_Noise_Ratio(cover,stego_LSB_6))
print("Secret-Reconstruction")
print("MSE =",Mean_Square_Error(secret,reconstructed_LSB_6))
print("PSNR =",Peak_Signal_to_Noise_Ratio(secret,reconstructed_LSB_6))
# Out:
# LBS_6
# Cover-Stego
# MSE = 93.13627371870109
# PSNR = 28.47361072330605
# Secret-Reconstruction
# MSE = 3.4735732100938965
# PSNR = 42.75703473993219

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(cover[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("cover histogramme")
# Out:
# Text(0.5, 1.0, 'cover histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(stego_LSB_2[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("stego_LSB_2 histogramme")
# Out:
# Text(0.5, 1.0, 'stego_LSB_2 histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(stego_LSB_4[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("stego_LSB_4 histogramme")
# Out:
# Text(0.5, 1.0, 'stego_LSB_4 histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(stego_LSB_6[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("stego_LSB_6 histogramme")
# Out:
# Text(0.5, 1.0, 'stego_LSB_6 histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(secret[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("secret histogramme")
# Out:
# Text(0.5, 1.0, 'secret histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(reconstructed_LSB_2[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("reconstructed_LSB_2 histogramme")
# Out:
# Text(0.5, 1.0, 'reconstructed_LSB_2 histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(reconstructed_LSB_4[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("reconstructed_LSB_4 histogramme")
# Out:
# Text(0.5, 1.0, 'reconstructed_LSB_4 histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(reconstructed_LSB_6[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("reconstructed_LSB_6 histogramme")
# Out:
# Text(0.5, 1.0, 'reconstructed_LSB_6 histogramme')

# %% [markdown]
# ## DCT

# %%
stego_DCT = cv2.imread(os.path.abspath("../Images/stego_DCT.png"),1)
stego_DCT = cv2.cvtColor(stego_DCT, cv2.COLOR_BGR2RGB)

stego_DCT_noise = cv2.imread(os.path.abspath("../Images/stego_DCT_noise.png"),1)
stego_DCT_noise = cv2.cvtColor(stego_DCT_noise, cv2.COLOR_BGR2RGB)

reconstructed_DCT = cv2.imread(os.path.abspath("../Images/reconstructed_DCT.png"),1)
reconstructed_DCT = cv2.cvtColor(reconstructed_DCT, cv2.COLOR_BGR2RGB)

reconstructed_DCT_noise = cv2.imread(os.path.abspath("../Images/reconstructed_DCT_noise.png"),1)
reconstructed_DCT_noise = cv2.cvtColor(reconstructed_DCT_noise, cv2.COLOR_BGR2RGB)

# %%
print("DCT 1")
print("Cover-Stego")
print("MSE =",Mean_Square_Error(cover,stego_DCT))
print("PSNR =",Peak_Signal_to_Noise_Ratio(cover,stego_DCT))
print("Secret-Reconstruction")
print("MSE =",Mean_Square_Error(secret,reconstructed_DCT_noise))
print("PSNR =",Peak_Signal_to_Noise_Ratio(secret,reconstructed_DCT_noise))
# Out:
# DCT 1
# Cover-Stego
# MSE = 0.0
# PSNR = 100
# Secret-Reconstruction
# MSE = 106.44831157081377
# PSNR = 27.89341153353764

# %%
print("DCT 2")
print("Cover-Stego")
print("MSE =",Mean_Square_Error(cover,stego_DCT_noise))
print("PSNR =",Peak_Signal_to_Noise_Ratio(cover,stego_DCT_noise))
print("Secret-Reconstruction")
print("MSE =",Mean_Square_Error(secret,reconstructed_DCT))
print("PSNR =",Peak_Signal_to_Noise_Ratio(secret,reconstructed_DCT))
# Out:
# DCT 2
# Cover-Stego
# MSE = 106.44076682316118
# PSNR = 27.893719359782082
# Secret-Reconstruction
# MSE = 2.7443478579812206
# PSNR = 43.780407713926444

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(stego_DCT[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("stego_DCT histogramme")
# Out:
# Text(0.5, 1.0, 'stego_DCT histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(reconstructed_DCT_noise[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("reconstructed_DCT_noise histogramme")
# Out:
# Text(0.5, 1.0, 'reconstructed_DCT_noise histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(stego_DCT_noise[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("stego_DCT_noise histogramme")
# Out:
# Text(0.5, 1.0, 'stego_DCT_noise histogramme')

# %%
colors = ("red", "green", "blue")

plt.figure()
plt.xlim([0, 255])
for (channel_id, color) in enumerate(colors):
    histogram, bin_edges = np.histogram(reconstructed_DCT[:, :, channel_id], bins=256, range=(0, 255))
    plt.plot(histogram, color=color)

plt.xlabel("color value")
plt.ylabel("pixel count")
plt.title("reconstructed_DCT histogramme")
# Out:
# Text(0.5, 1.0, 'reconstructed_DCT histogramme')

# %%
print(reconstructed_DCT)
# Out:
# [[[200 165   0]
#   [207 173   0]
#   [217 187   0]
#   ...
#   [233 208 168]
#   [233 208 168]
#   [233 208 167]]
#
#  [[200 165   0]
#   [208 174   0]
#   [217 187   0]
#   ...
#   [233 208 168]
#   [233 208 168]
#   [233 208 167]]
#
#  [[200 165   0]
#   [208 174   0]
#   [218 188   0]
#   ...
#   [233 208 168]
#   [233 208 167]
#   [233 208 167]]
#
#  ...
#
#  [[162 129   0]
#   [161 128   0]
#   [159 126   0]
#   ...
#   [ 17  12   6]
#   [ 18  11   5]
#   [ 17  10   4]]
#
#  [[162 129   0]
#   [161 128   0]
#   [159 126   0]
#   ...
#   [ 17  12   6]
#   [ 18  11   5]
#   [ 17  10   4]]
#
#  [[162 129   0]
#   [161 128   0]
#   [159 126   0]
#   ...
#   [ 17  12   6]
#   [ 18  11   5]
#   [ 17  10   4]]]

# %%
print(reconstructed_DCT_noise)
# Out:
# [[[  8 182   0]
#   [ 57 182   0]
#   [160 182   0]
#   ...
#   [ 29 243 236]
#   [ 84 243 236]
#   [139  27 236]]
#
#  [[222 182   0]
#   [112 182   0]
#   [ 57 182   0]
#   ...
#   [236 204 236]
#   [194 243 236]
#   [ 90  27 236]]
#
#  [[222 182   0]
#   [ 14 182   0]
#   [ 14 182   0]
#   ...
#   [139 204 236]
#   [ 97 204 236]
#   [139 204 236]]
#
#  ...
#
#  [[ 50  48   0]
#   [245  48   0]
#   [122  48   0]
#   ...
#   [ 31  66 113]
#   [ 86  66 113]
#   [196  66 113]]
#
#  [[215  48   0]
#   [167  48   0]
#   [215  48   0]
#   ...
#   [ 92  66 113]
#   [141  66 113]
#   [183  66 113]]
#
#  [[ 82  48   0]
#   [186  48   0]
#   [234  48   0]
#   ...
#   [245  66 113]
#   [141  66 113]
#   [238  66 113]]]
